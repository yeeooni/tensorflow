# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import math
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
 
dataframe = read_csv('/content/corona_data.csv', usecols=[3], engine='python', skipfooter=3)
print(dataframe)
dataset = dataframe.values
dataset = dataset.astype('float32')
 
scaler = MinMaxScaler(feature_range=(0, 1))
Dataset = scaler.fit_transform(dataset)
train_data, test_data = train_test_split(Dataset, test_size=0.2, shuffle=False)
print(len(train_data), len(test_data))
 
def create_dataset(dataset, look_back):
  x_data = []
  y_data = []
  for i in range(len(dataset)-look_back):
    data = dataset[i:(i+look_back), 0]
    x_data.append(data)
    y_data.append(dataset[i + look_back, 0])
  return np.array(x_data), np.array(y_data)
 
look_back = 3
x_train, y_train = create_dataset(train_data, look_back)
x_test, y_test = create_dataset(test_data, look_back)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
 
X_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
X_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
print(X_train.shape)
print(X_test.shape)
 
model = Sequential()
model.add(SimpleRNN(3, input_shape=(1, look_back)))
model.add(Dense(1, activation="linear"))
model.compile(loss='mse', optimizer='sgd')
model.summary()
 
model.fit(X_train, y_train, epochs=80, batch_size=1, verbose=1)
 
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)
TrainPredict = scaler.inverse_transform(trainPredict)
Y_train = scaler.inverse_transform([y_train])
TestPredict = scaler.inverse_transform(testPredict)
Y_test = scaler.inverse_transform([y_test])
print(len(testPredict))
 
trainScore = math.sqrt(mean_squared_error(Y_train[0], TrainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(Y_test[0], TestPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
 
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(TrainPredict)+look_back, :] = TrainPredict
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(TrainPredict)+(look_back)*2:len(dataset), :] = TestPredict
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
 
plt.show()
# Out:
#      Confirmed
# 0           24
# 1           24
# 2           27
# 3           27
# 4           28
# ..         ...
# 107      11190
# 108      11206
# 109      11225
# 110      11265
# 111      11344
#
# [112 rows x 1 columns]
# 89 23
# (86, 3) (86,)
# (20, 3) (20,)
# (86, 1, 3)
# (20, 1, 3)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 3)                 21
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 86/86 [==============================] - 2s 4ms/step - loss: 0.0410
# Epoch 2/80
# 86/86 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 3/80
# 86/86 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 4/80
# 86/86 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 5/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 6/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 7/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 8/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 9/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 10/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 11/80
# 86/86 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 12/80
# 86/86 [==============================] - 0s 2ms/step - loss: 9.3822e-04
# Epoch 13/80
# 86/86 [==============================] - 0s 2ms/step - loss: 9.7634e-04
# Epoch 14/80
# 86/86 [==============================] - 0s 2ms/step - loss: 9.3924e-04
# Epoch 15/80
# 86/86 [==============================] - 0s 2ms/step - loss: 8.9023e-04
# Epoch 16/80
# 86/86 [==============================] - 0s 2ms/step - loss: 8.7841e-04
# Epoch 17/80
# 86/86 [==============================] - 0s 2ms/step - loss: 8.4769e-04
# Epoch 18/80
# 86/86 [==============================] - 0s 2ms/step - loss: 8.1102e-04
# Epoch 19/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.8288e-04
# Epoch 20/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.6711e-04
# Epoch 21/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.5662e-04
# Epoch 22/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.2654e-04
# Epoch 23/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.1554e-04
# Epoch 24/80
# 86/86 [==============================] - 0s 2ms/step - loss: 7.0611e-04
# Epoch 25/80
# 86/86 [==============================] - 0s 2ms/step - loss: 6.5576e-04
# Epoch 26/80
# 86/86 [==============================] - 0s 2ms/step - loss: 6.6230e-04
# Epoch 27/80
# 86/86 [==============================] - 0s 2ms/step - loss: 6.3620e-04
# Epoch 28/80
# 86/86 [==============================] - 0s 2ms/step - loss: 6.2609e-04
# Epoch 29/80
# 86/86 [==============================] - 0s 2ms/step - loss: 6.0053e-04
# Epoch 30/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.7566e-04
# Epoch 31/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.7310e-04
# Epoch 32/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.6500e-04
# Epoch 33/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.4465e-04
# Epoch 34/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.3178e-04
# Epoch 35/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.2641e-04
# Epoch 36/80
# 86/86 [==============================] - 0s 2ms/step - loss: 5.0104e-04
# Epoch 37/80
# 86/86 [==============================] - 0s 3ms/step - loss: 4.8361e-04
# Epoch 38/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.7371e-04
# Epoch 39/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.7116e-04
# Epoch 40/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.4361e-04
# Epoch 41/80
# 86/86 [==============================] - 0s 3ms/step - loss: 4.4797e-04
# Epoch 42/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.3976e-04
# Epoch 43/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.1853e-04
# Epoch 44/80
# 86/86 [==============================] - 0s 2ms/step - loss: 4.1937e-04
# Epoch 45/80
# 86/86 [==============================] - 0s 3ms/step - loss: 3.9629e-04
# Epoch 46/80
# 86/86 [==============================] - 0s 3ms/step - loss: 4.0331e-04
# Epoch 47/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.8514e-04
# Epoch 48/80
# 86/86 [==============================] - 0s 3ms/step - loss: 3.6026e-04
# Epoch 49/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.7083e-04
# Epoch 50/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.6022e-04
# Epoch 51/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.5984e-04
# Epoch 52/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.5021e-04
# Epoch 53/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.3590e-04
# Epoch 54/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.3129e-04
# Epoch 55/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.2437e-04
# Epoch 56/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.0805e-04
# Epoch 57/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.1475e-04
# Epoch 58/80
# 86/86 [==============================] - 0s 2ms/step - loss: 3.0266e-04
# Epoch 59/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.9681e-04
# Epoch 60/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.7930e-04
# Epoch 61/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.8105e-04
# Epoch 62/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.7922e-04
# Epoch 63/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.7077e-04
# Epoch 64/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.5998e-04
# Epoch 65/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.5222e-04
# Epoch 66/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.5927e-04
# Epoch 67/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.5043e-04
# Epoch 68/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.4332e-04
# Epoch 69/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.4490e-04
# Epoch 70/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.3725e-04
# Epoch 71/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.3284e-04
# Epoch 72/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.2859e-04
# Epoch 73/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.2531e-04
# Epoch 74/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.1683e-04
# Epoch 75/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.1390e-04
# Epoch 76/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.1055e-04
# Epoch 77/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.0571e-04
# Epoch 78/80
# 86/86 [==============================] - 0s 2ms/step - loss: 2.0482e-04
# Epoch 79/80
# 86/86 [==============================] - 0s 2ms/step - loss: 1.9706e-04
# Epoch 80/80
# 86/86 [==============================] - 0s 2ms/step - loss: 1.9980e-04
# 3/3 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 36ms/step
# 20
# Train Score: 152.95 RMSE
# Test Score: 218.44 RMSE
